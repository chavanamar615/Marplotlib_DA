# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y=x**2
y
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
plt.plot(x,y)
plt.xlabel="Numbers"
plt.ylabel="Square of Numbers"
plt.title="Numbers 1_5"

# %%
plt.plot(x,y,color="red",markersize=15,marker="*",markeredgecolor="black",linestyle="dashed",linewidth=5)

# %%
plt.plot(x,y,"go--")

# %%
df=pd.read_csv("C:\\Users\\sspm\\Downloads\\cars93.csv")
df
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25         Driver only
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
df.shape
# Out:
# (93, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df["AirBags"].value_counts()
# Out:
# AirBags
# Driver only           57
# Driver & Passenger    22
# Name: count, dtype: int64

# %%
df["AirBags"]=df["AirBags"].fillna("Driver only")

# %%
df["AirBags"].value_counts()
# Out:
# AirBags
# Driver only           71
# Driver & Passenger    22
# Name: count, dtype: int64

# %%
df["AirBags"].value_counts().index
# Out:
# Index(['Driver only', 'Driver & Passenger'], dtype='object', name='AirBags')

# %%
df["AirBags"].value_counts().values
# Out:
# array([71, 22], dtype=int64)

# %%
df["AirBags"].unique()
# Out:
# array(['Driver only', 'Driver & Passenger'], dtype=object)

# %% [markdown]
# ## plt.bar(df["AirBags"].unique(),df["AirBags"].value_counts().values,color="red")

# %%
df["Type"].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
df["Type"].value_counts().values
# Out:
# array([22, 21, 16, 14, 11,  9], dtype=int64)

# %%
df["Type"].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
plt.bar(df["Type"].unique(),df["Type"].value_counts().values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.hist(df["Price"])
# Out:
# (array([25., 23., 23.,  8.,  6.,  5.,  1.,  1.,  0.,  1.]),
#  array([ 7.4 , 12.85, 18.3 , 23.75, 29.2 , 34.65, 40.1 , 45.55, 51.  ,
#         56.45, 61.9 ]),
#  <BarContainer object of 10 artists>)

# %%
df["Price"].value_counts()
# Out:
# Price
# 15.9    3
# 10.0    2
# 19.5    2
# 11.3    2
# 15.7    2
#        ..
# 19.3    1
# 12.2    1
# 25.8    1
# 15.6    1
# 26.7    1
# Name: count, Length: 81, dtype: int64

# %%
plt.hist(df["MPG.city"])
# Out:
# (array([25., 24., 20.,  8.,  9.,  4.,  0.,  1.,  1.,  1.]),
#  array([15. , 18.1, 21.2, 24.3, 27.4, 30.5, 33.6, 36.7, 39.8, 42.9, 46. ]),
#  <BarContainer object of 10 artists>)

# %%
arr1=np.array([10,20,45,67,89,34,76,34,23])
plt.hist(arr1,bins=20,color="black")
plt.xlabel("value in range")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 arr1=np.array([10,20,45,67,89,34,76,34,23])
#       2 plt.hist(arr1,bins=20,color="black")
# ----> 3 plt.xlabel("value in range")
#
# TypeError: 'str' object is not callable

# %%
plt.boxplot(df["Price"])

# %%
df["Price"].describe()

# %%
df.loc[df["Price"]>40,"Price"]=df["Price"].mean()  #it replace less than 40 value over mean value

# %%
df["Price"].describe()

# %%
df1=pd.read_csv("googleplaystore.csv")
df1

# %%
df1.shape[1]  #it gives how many columns

# %%
df1.columns   #column names present in dataframe

# %%
df1.head()

# %%
df1.info()

# %%
df1["App"].value_counts()

# %%
df1["App"].unique()

# %%
df1["App"].value_counts().values

# %%
df1["Rating"].describe()

# %%
df1["Rating"].info()

# %%
df1["Rating"].mode()

# %%
df1["Rating"].median()

# %%
arr=np.array([13,20,34,56,57,89,23,34])
arr

# %%
np.median(arr)

# %%
df1["Type"].mode()

# %%
df1["Rating"]

# %%
plt.boxplot(df1["Rating"])

# %%
df=pd.read_csv("Iris.csv")
df

# %%
plt.boxplot(df["Sepal_Length"])

# %%
df["Sepal_Length"].mean()

# %%
df.info()

# %%
df

# %%
df1=pd.read_csv("googleplaystore.csv")
df1

# %%
df1.info()

# %%
df1.isna()   #It gives ans in true or false

# %%
df1.isna().sum()  #it gives ans in numerical value

# %%
m=df1["Rating"].mean()
m

# %%
df1["Rating"]=df1["Rating"].fillna(m)     #OR

# %%
df1["Rating"]=df1["Rating"].fillna(df1["Rating"].mean())  #it fill the blank using Rating.mean()

# %%
df1.isna().sum()

# %%
df=pd.read_csv("cars93.csv")
df

# %%
df.head()

# %%
df["Type"].value_counts

# %%
lab=df["Type"].unique()
lab

# %%
val=df["Type"].value_counts().values
val

# %%
plt.pie(x=val,labels=lab)

# %%
plt.pie(x=val,labels=lab,colors=["brown","black","red","green","yellow","pink"]) #it gives color to pie

# %%
plt.pie(x=val,labels=lab,colors=["brown","black","red","green","yellow","pink"],autopct="%1.2f%%")  #it gives %

# %%
plt.pie(x=val,labels=lab,colors=["brown","black","red","green","yellow","pink"],autopct="%1.3f%%")  #it gkives % 
#after point how many number will get after .

# %%
plt.pie(x=val,labels=lab,colors=["brown","black","red","green","yellow","pink"],autopct="%1.2f%%",explode=(0.0,0.0,0.0,0.2,0.0,0.0))
#it will piece the pie chart

# %%
plt.pie(x=val,labels=lab)

# %%
plt.scatter(df["Price"],df["MPG.city"],color="red")

# %%
plt.scatter(df["Price"],df["MPG.city"],color="red")
plt.xlabel("Price")
plt.ylabel("MPG.city")

# %%
plt.scatter(df["Price"],df["MPG.city"],color="red")
plt.xlabel("Price")
plt.ylabel("MPG.city")
plt.show()
